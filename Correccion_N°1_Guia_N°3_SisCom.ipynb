# %% [markdown]
# ![logo_UTN.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# # SISTEMAS DE COMUNICACIONES
#
# ### Guia de problemas N°: 3
# ### Modulacion exponencial
# ### Grupo N°: 1
# ### Integrantes:
#
# *   Goyret, Marcos
# *   Destefano, Martin
# *   Sandomir, Uriel
# *   Gomez, Julian
# *   Glecer, Bruno
#
# ### Curso: R4001
#
# [Enunciados](https://aulasvirtuales.frba.utn.edu.ar/pluginfile.php/798956/mod_resource/content/7/GP%20-%20Modulacion%20Exponencial%20-%202023.pdf)

# %% [markdown]
# #Ejercicio 1 - ok

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# Am = 1 V
# Fmax = 5kHz
# Fc = 89 MHz
# Kf = 3kHz/V
#
# a) Calculando $β$ podemos determinar si es NBFM o WBFM:
#
# $β = \frac{Am \cdot Kf}{ F_{\text{max}}} = 0.6$
#
# Se puede considerar NBFM o justo en el limite segun bibliografia o lo visto en clase, por eso calculemos para ambos casos:
#
# Si suponemos NBFM:
#
# $$ B_{T} = 2B  = 10kHz$$
#
# Si suponemos WBFM:
#
# $$ B_{T} = 2(β+1)Fmax = 16kHz$$
#
# Para ambos casos verificamos que el ancho de banda no es 6 kHz como el enunciado propone, por lo tanto no se cumple el ahorro respecto de AM.
#
# b) Si suponemos WBFM:
#
# $β = \frac{Am \cdot Kf}{ F_{\text{max}}} = 200$
#
# $$ B_{T} = 2(β+1)Fmax = 2.01MHz $$
#
# En este caso cambiamos la sensibilidad del modulador, por lo que se producen mayores variaciones del ancho de banda, y como la frecuencia del mensaje no cambia, el ancho de banda depende practicamente del kf.
#
# c) El ancho de banda de transmision en ambos casos es el que se detallo anteriormente.
#
# En a:
# Si suponemos NBFM:
#
# $$ B_{T} = 2B  = 10kHz$$
#
# Si suponemos WBFM:
#
# $$ B_{T} = 2(β+1)Fmax = 16kHz$$
#
# En b:
# $$ B_{T} = 2(β+1)Fmax = 2.01MHz $$

# %% [markdown]
# #Ejercicio 2 - OK

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# Fc = 100 MHz
#
# Fm = [200 - 2500Hz]
#
# B = 8kHz
#
# a) Si se supone ancho de banda de Carlson:
#
# $$ B_{T} = 2ΔF + 2Fmax = 8kHz $$
#
# Pero sabes que Fmax = 2500 Hz.
#
# Entonces:
#
# $$ ΔF = 1500 Hz $$
#
# Como depende linealmente de la amplitud, la nueva $ΔF$ sera el doble de la original.
#
# $$ B_{T} = 2ΔF + 2Fmax = 2*3000 + 2*2500 = 11kHz $$
#
# b) $$ B_{T} = 2ΔF + 2Fmax = 2*1500 + 2*5000 = 13kHz $$
#
# c) $β$ en PM no depende de la frecuencia maxima del mensaje, por lo tanto, usando Carlson sabemos que:
#
# $$ B_{T} = 2(β+1)(2*Fmax) = 16kHz$$
#
# d) En el inciso a se modifico la relacion de desviacion y la maxima desviacion, ya que, se modifico la Am.
#
# En el inciso b, se modifico la relacion de desviacion, pero no la maxima desviacion. Esto se debe a que el parametro modificado no fue ni la amplitud ni la Kf.
#
# En el inciso C, se modifcio la frecuencia del mensaje, cuaya influencia es nula en la desviacion de fase, por lo tanto no se modifico ni la desviacion ni la relacion de desviacion.

# %% [markdown]
# ![20230704_210619.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![20230704_210634.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Ejercicio 3 - corregido

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# a) $P_{1\Omega} = \frac{Ac^2}{2}.\frac{1}{1\Omega} = 112.5 W$
# <br><br>
# b) $\beta_2 = \frac{\Delta f}{f_m} = \frac{Df.A_m}{f_m} = \frac{20\frac{Hz}{V}.15V}{11KHz} = 27.27$
# <br><br>
# $ \beta_1 = \frac{20K.15}{2KHz} = 150$
# <br><br>
# $\boxed { \beta_1 ω_1 = 604KHz}$
# $\boxed { \beta_2 ω_2 = 622KHz}$
# <br><br>
# ![image.png](data:image/png;base64,...)
# <br><br>
# Para saber el ancho de banda total de la señal habria que convolucionar todos los Jn(B) pero a simple vista se puede observar que al convolucionar el tono B1 con el tono B2 sus componentes quedarian practicamente despreciables, por lo que se puede tomar al ancho de banda de la señal como aproximadamente 625KHz
# $
# % \Delta f= (A_1 + A_2)Kf = 120KHz$
# $
# %B_T = 2\Delta f + 2F_{MAX} = 262KHz$
# <br><br>
#
# c) $m(t) = 2sen(2π.2000Hz.t) + 4sen(2π.11000Hz.t + \phi)$
# <br><br>
#
# d)$m'(t) = 2sen(2π.2000Hz.t) + 4sen(2π.11000Hz.t + \phi) + 2V$
# <br><br>
# $θ(t) = 2\pi.Df ∫m(t) dt = 2sen(2π⋅2000Hz\cdot t) + 4sen(2π.11000Hz.t + \phi) +2t\cdot 2 \cdot \pi \cdot Df $
# <br><br>
# $θ(t) = 2sen(2π⋅2000Hz\cdot t) + 4sen(2π.11000Hz.t + \phi) + 80K\cdot \pi\cdot t $
#
# e) $\boxed{\Delta f= 120KHz}$<br>
# <br>$ F_{MAXmod} = 11KHz $<br><br>
# $ β = \frac{Δf}{F_{MAXmod}} = 10.91  $
# <br><br>
# $Δθ = max{θ(t)} = 2 + 4$
# <br><br>
# $\boxed{Δθ = 6}$
#
#
# <br><br>
#
# f)$ S(f) = 7.5\delta(f - fc) + 7.5\delta(f + fc) + j\delta(f - 2000) - j\delta(f + 2000) + 2j\delta(f - 11000) - 2j\delta(f + 11000)$
# <br><br>
# $\boxed{|S(f)| = 7.5\delta(f - fc) + 7.5\delta(f + fc) + \delta(f - 2000) - \delta(f + 2000) + 2\delta(f - 11000) - 2\delta(f + 11000)}$

# %% [markdown]
# ## Entrega 2

# %% [markdown]
# b) El ancho de banda se puede calcular por Carlson, calculando la desviacion maxima por definicion:
#
# $$ ΔF = \frac{1}{2π}\frac{dΦ(t)}{dt} $$
#
# $$ ΔF = 2 * 2.10^3 +4*11.10^3 $$
#
# $$ ΔF = 48KHz $$

# %% [markdown]
# c) expreison de m(t)
#
# $$ m(t)=\frac{1}{2π}\frac{1}{D_f}\frac{dΦ(t)}{dt} $$
# $$ m(t)=\frac{1}{2π}\frac{1}{D_f}(2*cos(2\pi2*10^3t)*2\pi210^3+4*cos(2\pi11*10^3t+\phi)*2\pi11*10^3) $$
#
# $$ m(t)=\frac{2*2*10^3}{D_f}cos(2\pi2*10^3t)+\frac{4*11*10^3}{D_f}*cos(2\pi11*10^3t+\phi) $$
#
# d) s(t) si a m(t) le agregamos 2V continuos
#
# $$ m(t)=\frac{2*2*10^3}{D_f}cos(2\pi2*10^3t)+\frac{4*11*10^3}{D_f}*cos(2\pi11*10^3t+\phi) +2V $$
# $$ \phi(t)=2*sin(2\pi2*10^3t)+4*sin(2\pi11*10^3t+\varphi) +4\pi k_ft$$
#
# $$ s(t)=15*cos[2\pi f_ct+2*sin(2\pi2*10^3t)+4*sin(2\pi11*10^3t+\phi) +4\pi k_ft] $$
#
# e)
#
# $$ \Delta\phi = 2+4=6 $$
#
# $$ ΔF = Max\frac{1}{2π}\frac{dΦ(t)}{dt} $$
#
# $$ ΔF = 2 * 2.10^3 +4*11.10^3 + 40k$$
#
# $$ ΔF = 88KHz $$
#
# f) se corresponde la fomrula:
# $$ |S(f)| = |G(f)| = A_c \sum_n \sum_m J_n(\beta_1) J_m(\beta_2) \delta(f - nf_1 - nf_2) $$

# %% [markdown]
# #Ejercicio 4 - corregido

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# x(t) = 0.3V cos($ω_{m}t$)
#
# kf = 20kHz/V
#
# a) La amplitudes que se ven en el espectro son las mismas, esto significa que en ambos casos el beta tiene el mismo valor, por lo tanto:
#
# $$β = \frac{k_{f}Am}{Fmax} = \frac{2}{3}$$
#
# De la figura se sabe que Fmax1 = 9kHz
#
# b) Como el beta es igual, se tiene que haber modificado Am y/o Fm, veamos:
#
# De la figura Fmax2 = 15kHz
#
# $$β = \frac{k_{f}Am1}{Fmax1} = \frac{k_{f}Am2}{Fmax2}$$
#
# Entonces $Am2 = 0.5V$
#
# c) $ΔF = 10kHz$
#
# $$ B_{T} = 2ΔF + 2Fmax = 50kHz$$
#
# d) Dp = 4 rad/V
#
# $$ B_{T} = 2(β+1)Fmax = 66kHz $$
#
# $$ β_{1} = β_{2} $$
#
# Como los betas son iguales, y la constante Dp no cambia, la amplitud tampoco lo hace y el cambio en Fm no afecta al beta en modulacion de fase.

# %% [markdown]
# ## Entrega 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Ejercicio 5

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 2

# %% [markdown]
# c)
# La potencia 2 es de una cuadrada polar, por lo que:
# $$ P_2 = 2^2 = 4W $$

# %% [markdown]
# #Ejercicio 6 - CORREGIDO

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# P = 250 W
#
# A) β = 2.405
#
# Como sabemos que
#
# $$ P = \frac{Ac^2}{2} \sum_{n=-\infty}^{\infty} J_n^2(\beta) = 250 W$$

# %%
import math

def suma_cuadrados(array):
    suma = 0
    for elemento in array:
        suma += elemento**2
    return suma

J_array = [0.003, 0.520, 0.431, 0.198, 0.064, 0.016, 0.003]
resultado = suma_cuadrados(J_array)
Potencia = 250

Ac = math.sqrt(250 * 2/resultado)
print(Ac)
# Out:
# 31.631159970019375

# %% [markdown]
# Como vemos el valor de nuestra amplitud de portadora es 31.63 V. Entonces podemos calcular su potencia:
#
# $$ Pc = \frac{(Ac*J0)^2}{2} = 4.5mW = 6.53dBm $$
#
# $$ 40dBm = 10 W = PC $$
#
# Por lo tanto, J0 debe ser:
#
# $$ J0 = \frac{\sqrt{10*2}}{Ac} $$
#
# Minimamente J0 debe ser: 0.1414
#
# Los siguientes valores de β cumplen esta caracteristica:
#
# - β1 = 2.7
# - β2 = 2.8
# - β3 = 2.9
#
# b) Para que sean significativas, el valor de la potencia de la banda lateral debe ser mayor 2.5 W
#
# Para β1 = 2.7
#
# $$ 2.5 W < \frac{(Ac*Jn)^2}{2} → Jn > 0.00706 $$

# %%
def cuadrado_condicional(array):
    resultado = []
    for elemento in array:
        if elemento > 0.007:
            resultado.append((31.62*elemento)**2/2)
    return resultado

array = [0.442, 0.470, 0.254, 0.095, 0.027, 0.006]
resultado = cuadrado_condicional(array)
for i in range(0,len(resultado)):
  print("Potencia banda lateral",i , resultado[i])
# Out:
# Potencia banda lateral 0 97.66484704080001
# Potencia banda lateral 1 110.43060498
# Potencia banda lateral 2 32.2523354952
# Potencia banda lateral 3 4.511707605000001
# Potencia banda lateral 4 0.3644359938

# %% [markdown]
# c) Graficamente podemos ver que la interseccion sucede en β = 1.5, por lo tanto los otros parametros seran:
#
# - ΔF = 15kHz
# - $B_{T} = 50kHz$

# %% [markdown]
# ## Entrega 2
#
# Partimos que la potencia dada es correcta, osea:
#
# P = 250 W
#
# Podriamos volver a realizar los calculos, sumandoles las componentes faltantes pero para mayor sencillez haremos los recomendado, ya que dentro de la formula de la potencia total tenemos la de la potencia de la portadora, la calculamos:
#
# $$ P_{FM} = \frac{Ac^2}{2} $$
#
# $$ A_{c} = 22.36 V $$
#
# $$ P_{c} = 2.25mW = 3.52dBm $$
#
# $$ 40dBm = 10 W = PC $$
#
# Por lo tanto, J0 debe ser:
#
# $$ J0 = \frac{\sqrt{10*2}}{Ac} $$
#
# Minimamente J0 debe ser: 0.2
#
# Los siguientes valores de β cumplen esta caracteristica:
#
# - β1 = 2.0
# - β2 = 1.9
# - β3 = 1.8
#
# b) Para que sean significativas, el valor de la potencia de la banda lateral debe ser mayor 2.5 W
#
# Para β1 = 1.8
#
# $$ 2.5 W < \frac{(Ac*Jn)^2}{2} → Jn > 0.1414256 $$

# %%
def cuadrado_condicional(array):
    resultado = []
    for elemento in array:
        if elemento > 0.1414256:
            resultado.append((22.36*elemento)**2/2)
    return resultado

array = [0.582, 0.306, 0.099, 0.023, 0.027]
resultado = cuadrado_condicional(array)
for i in range(0,len(resultado)):
  print("Potencia ",i+1 , resultado[i])
# Out:
# Potencia  1 84.67585139519997
# Potencia  2 23.4075767328

# %% [markdown]
# #Ejercicio 7 - CORREGIDO

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# $-47 dBm = 20nW $
# <br><br>
# a)
# $P_m = P_{50\Omega} . 50 \Omega = 20nW . 50\Omega = 1\mu W$
# <br><br>
# $A_m = \sqrt{2P_m} = 1.41mV$
# <br><br>
# $A_C = \frac{A_m}{tan(\Delta \Theta)} = 8.02mV$
# <br><br>
# $P_C =\frac{A_C^2}{2} $
# <br><br>
# $\boxed{ P_C = 32.16\mu W = -14.93dBm}$
# <br><br>
#
# b)
# $A_{MAX} = \frac{A_C}{cos(\Delta \Theta)} = 8.144mV$
# <br>
# $A_{MIN} = A_C$
# <br><br>
# $m = \frac{A_{MAX} - A_{MIN}}{2\cdot A_C}$
# <br><br>
# $\boxed{m_{FM} = 0.0077}$
#
#
#
# c) Si se elimina el desfasaje: $m = \frac{A_m}{A_C}$
# <br><br>
# $\boxed{m_{AM} = 0.176 }$
# <br><br>
#
# d) La frecuencia sigue siendo la misma (6KHz)
# <br><br>
# e) La frecuencia sera ahora el doble que la del tono (12KHz)

# %% [markdown]
# ## Entrega 2

# %% [markdown]
# $-47 dBm = 20nW $
# <br><br>
# a)
# <br><br>
# $A_1BL = \sqrt{\frac{P_{2BL}}{2}2R} = 1mV$
# <br><br>
# $A_C = \frac{2*A_1BL}{tan(\Delta \Theta)} = 11.34mV$
# <br><br>
# $P_C =\frac{A_C^2}{2R} $
# <br><br>
# $\boxed{ P_C = 1.2865\mu W = -28.9dBm}$
# <br><br>
#
# b)
# $A_{MAX} = \frac{A_C}{cos(\Delta \Theta)} = 11.51mV$
# <br>
# $A_{MIN} = A_C$
# <br><br>
# $m = \frac{A_{MAX} - A_{MIN}}{ A_{MAX} + A_{MIN}}$
# <br><br>
# $\boxed{m_{FM} = 0.00744}$

# %% [markdown]
# #Ejercicio 8 - CORREGIDO

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# a)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# b) ΔF = (0.052V * 1600Hz/V * 90)/15000kHz = 0.5
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# c)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 2

# %% [markdown]
# a)$$ ΔF_{WBFM} = 72KHz  $$
#
# $$ \beta_{WBFM} =  \frac{ΔF_{WBFM}}{Fm} $$
#
# $$ \beta_{WBFM} = \frac{72Khz}{10Khz} $$
#
# $$ \beta_{WBFM} = 7.2 $$
#
# $$ ΔFnbfm = \frac{72Khz}{90} =800Hz $$
#
# $$ \beta_{NBFM} = \frac{72Khz}{10Khz*90} = 0.08 $$

# %% [markdown]
# b)
#
# Para el caso de NBFM
# $$ ΔF_{NBFM} = 0.052*1600 =83.2Hz $$
# $$ β = \frac{ΔF_{NBFM}}{Fm} = \frac{83.2Hz}{15KHz}=0.00554$$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para el caso de WBFM antes del mezclador y el filtrado solo se veria afectada su frecuencia de portadora, ya que, solo posee tres componentes significativas. β=0.5
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Ejercicio 9 - OK

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El DC BLOCK, nos sirve para filtrar la continua para la inyeccion en el superheterodino.

# %% [markdown]
# b)
# A la salida del diferenciador:
#
# $$ V_{out} = -V_{L} [ω_{c} + \frac{dΦ}{dt}] sen[ω_{c}t+Φ(t)] $$
#
# Siendo $Φ(t) = K_{f} \int_{-\infty}^{t} m(λ) dλ$
#
# $$ V_{out} = -V_{L} ω_{c} [1 + \frac{2𝜋K_{f}m(t)}{ω_{c}}] sen[ω_{c}t+ K_{f} \int_{-\infty}^{t} m(λ) dλ ] $$
#
# Es una expresion de AM:
#
# $(1 + \frac{2𝜋K_{f}m(t)}{ω_{c}}) = (1 + \frac{K_{f}m(t)}{ω_{c}/2π})$
#
# Como Fc = Fi antes del detector de envolvente:
#
# KfAm = ΔF
#
# $$ mF_{c} = ΔF $$
#
# $$ m = \frac{11.6 - 8.4}{11.6+8.4} = 0.16 $$
#
# $$ ΔF = 72.8kHz $$
#
# c) $$ Ac + Am = Amax $$
# $$ Ac - Am = Amin $$
#
# Resolviendo el sistema:
#
# $$ Am = 1.6 V $$
# $$ Ac = 10 V $$

# %% [markdown]
# #Ejercicio 10 - Corregir D

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# a)
#
# $$ \frac{Ac^2}{2} = 5 W $$
#
# $$ P_{y(t)} = \frac{Ac^2}{2} (1+\frac{m^2}{2}) $$
#
# $$ m = 0.6 $$
#
# b) $$ B_{fm} = 2ΔF + 2Fm = 58kHz $$
#
# $$B_{AM} = 200kHz $$
#
# $$DR = 6.25 $$
#
# c) El indice de modulacion de AM no cambia, debido a que las amplitudes son las mismas.
#
# Para el nuevo ancho de banda de FM debemos calcular la nueva ΔF:
#
# ΔF = 27,5 kHz
#
# Por lo tanto B = 63kHz
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 2

# %% [markdown]
# b) Para calcular el ancho de banda de AM, hay que tener en cuenta que viene en conjunto con la FM, por lo tanto:
#
#
# $$ B_{T} = B_{AM} + \frac{B_{FM}}{2} $$
#
# Donde:
#
# $ B_{AM} = 200KHz $
#
# $ B_{FM} = 58KHz $
#
# $ ⇒ $$ B_{T} = B_{AM} + B_{FM} = 258KHz $
#
# d)
