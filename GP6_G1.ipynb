# %% [markdown]
# ![logo_UTN.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# # SISTEMAS DE COMUNICACIONES
#
# ### Guia de problemas N°: 6
# ### Teoria de la informacion
# ### Grupo N°: 1
# ### Integrantes:
#
# *   Goyret, Marcos
# *   Destefano, Martin
# *   Sandomir, Uriel
# *   Gomez, Julian
# *   Glecer, Bruno
#
# ### Curso: R4001
#
# [Enunciados](https://aulasvirtuales.frba.utn.edu.ar/pluginfile.php/799046/mod_resource/content/5/GP%20Teor%C3%ADa%20de%20la%20informaci%C3%B3n%20-%202023.pdf)

# %% [markdown]
# #Ejercicio 1
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# a) Cada digito tiene 10 valores posibles, por lo que necesitamos 4 binits.
# b) Cada tambor tiene 100 valores, por lo que necesitamos 7 binits
# c) En total, hay $10^6$ combinaciones posibles, por lo que necesitamos 20 binits.

# %% [markdown]
# #Ejercicio 2
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# a)
#
# $H = \sum_{i=1}^{M} P_i \log_2\left(\frac{1}{P_i}\right) \text{ bits/mensaje}$
# $H = \frac{1}{2}\log_2(2) + \frac{1}{4}\log_2(4) + 2\left(\frac{1}{8}\log_2(8)\right) = 1.75 \text{ bits/mensaje}$
# $R = \frac{H}{\frac{1}{\tau}} = \frac{1.75 \text{ bits/mensaje}}{0.25 \frac{\text{seg}}{\text{mensaje}}} = 7k \text{ bits/mensaje}$

# %% [markdown]
# b)
#
# El mensaje puede tomar 4 niveles de tension, por lo que es multinivel. Para transmitirlo en binario, haria falta un cdificador y decodificador, y seria un envio mas lento, o requeriria mayor ancho de banda.

# %% [markdown]
# ![b.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Ejercicio 3
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# <br><br>
# $R=116.000bps$
# <br>
# $N = 11\frac{binits}{char}$
# <br><br>
# a) $V_{char} = \frac{R}{N}$
# <br>
# $\boxed{V_{char} = 10545\frac{char}{s}}$
# <br><br>
# b) Si tenemos una pagina con 500 palabras, con promedio de 6 caracteres y un espacio por palabra, tenemos entonces en promedio, 3500 caracteres por pagina.
# El tiempo que tardaremos para transmitir una pagina estara dado por:
# <br>
# $T_{pag} = \frac{1}{V_{pag}}$
# <br>
# $V_{pag} = \frac{V{char}}{3500\frac{char}{pag}}$
# <br><br>
# Entonces:
# <br>
# $V_{pag} = 3.0128 \frac{s}{pag}$
# <br>
# $\boxed{T_{pag} = 0.332 s}$
# <br><br>
#
# c) $H = P_{esp} . N_{esp} .log_2(P_{esp}) + P_{vocal} . N_{vocal} .log_2(P_{vocal}) + P_{otro} . N_{otro} .log_2(P_{otro}) $
# <br><br>
# $H = \frac{1}{7}\cdot 1 \cdot 2.807 + \frac{3}{28} \cdot 5 \cdot 3.222 + \frac{1}{168} \cdot 54 \cdot 7.392$
# <br><br>
# $\boxed{H = 4.502 \frac{bits}{char}}$
# <br><br>
# d) La tasa de información transmitida seguirá siendo la misma, aunque, luego de
# ser codificada esta información, trabajaremos con una tasa de señalización, que
# será mayor o igual y dependerá de la cantidad de binits promedio que se use por cada caracter

# %% [markdown]
# #Ejercicio 4
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# <br><br>
#
# Tenemos 3840x2160 px con 4096 niveles equiprobables:
# <br><br>
# a) $l = 12\frac{bits}{px} $
# <br><br>
# $I_{img} = (3840 \cdot 2160 \cdot 12) bits$
# <br>
# $\boxed{I_{img} = 99.53Mbits}$
# <br><br>
#
# b) $C = 100 \frac{Mbits}{s}$
# <br><br>
# $T_{img} = \frac{I_{img}}{C}$
# <br><br>
# $\boxed{T_{img} = 0.9952s}$

# %% [markdown]
# #Ejercicio 5
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# a)
# Informacion de la imagen:
#
# $$ 1080⋅1920⋅10bits = 20.736Mbits/imagen $$
#
# Informacion de video (informacion por unidad de tiempo):
#
# $$ 1080⋅1920⋅10bits/imagenes⋅60 imagenes/segundos = 1.24416.10^9 bps$$
#
# b) $ SNR = 10^5 $
#
# $$ B = \frac{C}{Log_2 (1+10^5)} $$
#
# Si C = 1.24416.10^9 bps
#
# Reemplazamos C y obtenemos que B tiene que ser **74.906 MHz**
#
# c) Como la informacion por unidad de tiempo es 1.24416.10^9 bps
#
# Memoria = $ 1.24416.10^9 bps ⋅ 10 ⋅ 60 = 746.496 Gbits = 93.312 Gbytes $

# %% [markdown]
# #Ejercicio 6
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# a) Para saber si es posible transmitir el mensaje o no, es necesario calcular la entropia haciendo la sumatoria de las probabilidades por el logaritmo en base de dos de la inversa de las probabilidades:
#
# $$ H = P_i \cdot Log_{2}(\frac{1}{Pi}) $$

# %%
import numpy as np

P1 = 1/4
P2 = 1/8
r = 100


H = 3*P1*np.log2(1/P1) + 2*P2*np.log2(1/P2)
T_bits = 100 * H
print("La entropia es: ", H, "bits/simbolo")
print("R= ",T_bits, "bits/segundos")
# Out:
# La entropia es:  2.25 bits/simbolo
# R=  225.0 bits/segundos

# %% [markdown]
# Como R es menor a los 250 bps del canal, se puede transmitir.
#
# b)
#
# | Mensaje | Codificacion | Probabilidad |
# |----------|----------|----------|
# | m1  |  00  | 1/4   |
# | m2    | 01   | 1/4   |
# | m3    | 10   | 1/4   |
# | m4    | 110   | 1/8   |
# | m5    | 111   | 1/8   |
#
# c) $$ N = \frac{1}{4} ⋅ 2 + \frac{1}{4} ⋅ 2 + \frac{1}{4} ⋅ 2 + \frac{1}{8} ⋅ 3 + \frac{1}{4} ⋅ 3 =  2.25 \space binits/seg$$
#
# $ \boxed{R = r \cdot N = 225 binits/seg} $
#
# d) Como N = H, eficiencia es del 100%

# %% [markdown]
# #Ejercicio 7
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# A)
# Teniendo un B de 1Mhz en Banda Base el B real seria de 2*B por lo que sabiendo como obtener la capacidad
#
# $$ C=B*log_{2}(1+SNR)$$
# y sabiendo que la minima relacion ruido es necesaria para poder transmitir toda la informacion por el canal, es decir se necesita un C=R=20Mbits/seg
# por lo que despejando se obtiene
# $$ 20Mbits/seg=2MHz*log_{2}(1+SNR)$$
# $$ SNR=2^{10}-1$$
# $$ SNR=1023$$
# B)
# La tasa de simbolos disponible para transmitir, teniendo la minima SNR y por lo tanto la minima C seria
# $$\frac{R}{H}=\frac{20Mbits/seg}{2.3bits/simbolo}=8.6956\frac{simbolo}{segundo}$$

# %% [markdown]
# #Ejercicio 8
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# A)
# Siendo que para cada imagen se requiere transmitir
# $$ Informacion_{imagen}=300*400*log_{2}(32)=600Kbits    $$
# $$ Informacion_{video}=10*informacion_{imagen}=6Mbits $$
# El tiempo minimo de tranmision se calcula como:
# $$ T_{min}=\frac{Informacion_{imagen}}{Capacidad}$$
# y sabiendo que la ecuacion que describe la capacidad es
# $$ C=B*log_{2}(1+SNR)$$
# y sabiendo que el SNR se obtiene como
# $$ \frac{S}{N}=\frac{\frac{P_{s}}{A{tt}}*G_{Tx}*G_{Rx}}{K*T*B}=12,276782*10^{-3} $$
# De esta manera nos queda que
# $$C=8,80190Kbits/seg$$
# Y
# $$T_{min}=\frac{Informacion_{imagen}}{Capacidad}=\frac{600Kbits}{8,80190Kbits/seg}=68,1670segs$$
# B)
# No el tiempo no se reduce a la mitad debido al que la capacidad depende logaritmicamente de la SNR siendo asi que si el B es el doble en este caso la SNR es igual a
# $$B_{2}=2*B_{1}$$
# $$SNR_{2}=SNR_{1}/2=6,138391*10^{-3}$$
# y asi
# $$C=2*B_{1}*log_{2}(1+6,138391*10^{-3})=8,82767Kbits/seg$$
# $$T_{min}=\frac{Informacion_{imagen}}{Capacidad}=\frac{600Kbits}{8,82767Kbits/seg}=67,9597segs$$
# C)
# No hay manera posible incluso haciendo el ancho de banda infinito pues:
# $$B-> inf$$
# $$C=\frac{S}{N_{0}}*1,44=8,839283Kbits/segs$$
# $$T_{min}=67,8788segs$$

# %% [markdown]
# #Ejercicio 9
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# <br><br>
# $S = -80dBm = 10pW$
# <br><br>
# $C_{B\rightarrow∞} = 1.44 \frac{S}{k .T_O}  = 1.44 \frac{10pW}{4.10^{-21}}$
# <br>
# ${C_{B\rightarrow∞} = 3.9Gbps}$
# <br><br>
# $H = \frac{2}{3} \cdot log_2 (\frac{3}{2}) + \frac{1}{3} \cdot log_2 (\frac{3}{1}) = 0.9183 \frac{bits}{simbolo}$
# <br><br>
# $T_{prom} = \frac{1}{3} 0.5μs + \frac{2}{3} 0.25μs = \frac{0.333\mu s}{simbolo}$
# <br><br>
# $R = \frac{H}{T_{prom}} = 2.755\frac{Mbits}{s}$
# <br><br>
# Se pueden conectar entonces:
# <br>
# $N = \frac{C}{R} = \boxed{1415 \space fuentes}$

# %% [markdown]
# #Ejercicio 10
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Entrega 1

# %% [markdown]
# <br><br>
# $C_1 = B \cdot log_2(1 + SNR)$
# <br>
# $C_2 = 0.75 \cdot B \cdot log_2(1 + \frac{k.S}{N_o\cdot 0.75})$
# <br><br>
# El canal no cambia:
# <br>
# $C_1 = C_2 ⇒ B \cdot log_2(7) =  0.75 \cdot B \cdot log_2(1 + \frac{k.S}{N_o\cdot 0.75})$
# <br>
# $⇒ 2.807 = 0.75 \cdot log_2(1 + SNR\frac{k}{0.75})$
# <br>
# $⇒ 2^{\frac{2.807}{0.75}} - 1 = 6\frac{k}{0.75}$
# <br>
# $⇒\boxed{k = 1.548 \space veces }$
