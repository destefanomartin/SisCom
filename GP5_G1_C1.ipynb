# %% [markdown]
# ![logo_UTN.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# # SISTEMAS DE COMUNICACIONES
#
# ### Guia de problemas N°: 5
# ### Modulacion digital
# ### Grupo N°: 1
# ### Integrantes:
#
# *   Goyret, Marcos
# *   Destefano, Martin
# *   Sandomir, Uriel
# *   Gomez, Julian
# *   Glecer, Bruno
#
# ### Curso: R4001
#
# [Enunciados](https://aulasvirtuales.frba.utn.edu.ar/pluginfile.php/799041/mod_resource/content/4/GP%20Modulaci%C3%B3n%20digital%20-%202023.pdf)

# %% [markdown]
# # Ejercicio 1
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# a) En banda base:
#
# $$ B_{Tmin} = D/2 = R/2 = 9600 Hz $$
#
# En BPSK:
#
# $$ B_{T} = D = R = 19200 Hz $$
#
# b) No es posible usar una modulacion BPSK, se deberia optar por MPSK:
#
# $$ \frac{19200}{8000} = 2.4 $$
#
# $$ 8PSK ⇒ l = 3 $$
#
# $$ D = \frac{19200}{3} = 6400 Hz $$
#
# Se podria transmitir con 8PSK (señalizacion multinivel)
#
# c) $$ \frac{R}{D} = 3 $$

# %% [markdown]
# # Ejercicio 2
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# a) El tipo de modulacion es FSK
#
# ![image.png](data:image/png;base64,...)
#
# b) D = R = 1/tb = 1000 bauds/seg
#
# tb: tiempo de bit
#
# c) Como se asemeja a una modulacion FM, se utiliza ancho de banda de Carlson:
#
# $$ 2(ΔF + B) = B_{min} $$
#
# Siendo ΔF = 1MHz y B = D/2
#
# $$ 2(ΔF + B) = B_{min} = 2001kHz $$
#
# d) Para el minimo ancho de banda ΔF = D/2
#
# ⇒ BT = 2D -> 2KHz
#
# Frecuencia de espacio: 9MHz - D/2 = 8999.5KHz
# Frecuencia de marca: 9MHz + D/2 = 9000.5KHz
#
# e) Para MSK → ΔF = R/4 ⇒ ΔF = 250Hz
#
# $ B_{T} = 1500 Hz $
#
# f) Desv. frec : $\frac{2MHz⋅2}{D⋅2} = 2000 $
#
# Caso d)
#
# Desv. frec : $ \frac{1KHz⋅2}{D⋅2} = 1 $
#
# Caso e)
#
# Desv. frec : $ \frac{500Hz⋅2}{D⋅2} = 0.5 $

# %% [markdown]
# # Ejercicio 3
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 1 (pendiente D)

# %% [markdown]
# a) El tipo de modulacion se corresponde con 8PSK.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El bloque de procesamiento, incluye el convertidor digital analogico (DAC) tanto como el procesamiento de la señal en si.
# El filtro de coseno realzado va a acotar el ancho de banda de la señal y luego tenemos los mezcladores, uno que afecta la señal por el coseno y otro por el seno.
# Por ultimo, tenemos el sumador con el seno restandose a la señal cosenoidal.
#
# b)
#
# | Codigo | I           | Q           |
# |--------|-------------|-------------|
# | 000    | 0.92387953  | 0.382683432 |
# | 001    | 0.38268343  | 0.923879533 |
# | 010    | -0.38268343 | 0.923879533 |
# | 011    | -0.92387953 | 0.382683432 |
# | 100    | -0.92387953 | -0.38268343 |
# | 101    | -0.38268343 | -0.92387953 |
# | 110    | 0.38268343  | -0.92387953 |
# | 111    | 0.92387953  | -0.38268343 |
#
# c) Ancho de banda de nulo a nulo:
#
# $$ B_{T} = \frac{2R}{l} = \frac{2*6Mbps}{3} = 4MHz $$
#
# d)
#
# e) Eficiencia espectral con filtro de coseno realzado:
#
# $$ ɳ = \frac{l}{1+r} = \frac{3}{1.25} = 2.4 $$

# %% [markdown]
# ### Entrega 2
#
# d) ![null (1).png](data:image/png;base64,...)

# %% [markdown]
# # Ejercicio 4
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# a) Modulacion 16QAM
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El modulador es el mismo que el punto anterior, solo que hay que adaptar la cantidad de bits en la seccion de procesamiento de señal y utilizar los convertidores de 2 bits cada uno.
#
#
# b) Podemos calcular la potencia de un cuadrante y multiplicarla por los demas:
#
# $$ P_{1} = \frac{(3Ac)^2+(3Ac)^2}{2*50} = 9\frac{Ac^2}{50}$$
#
# $$ P_{2} = \frac{(3Ac)^2+(Ac)^2}{2*50} = 5\frac{Ac^2}{50}$$
#
# $$ P_{3} = \frac{(Ac)^2+(Ac)^2}{2*50} = \frac{Ac^2}{50}$$
#
# $$ P_{16QAM} = \frac{P_{1}+2*P_{2}+P_{3}}{4} = \frac{20Ac^2}{50*4} = \frac{1}{10} W = 20dBm $$
#
# c) $R = \frac{N}{ts} = \frac{4}{4μS} = 1MHz $
#
# d) Ancho de banda minimimo: Bmin = D = $\frac{R}{l} = 200kHz $
#
# e) En relacion al ruido, es conveniente usar una modulacion 16QAM ya que provee mayor distancia entre puntos. Con respecto a eficiencia energetica y factor de cresta la modulacion de 16PSK aventaja a 16QAM.

# %% [markdown]
# ### Entrega 2
#
# a)
#
# Se sabe que Ac = 1 V, por lo que tabla quedara asi:
#
# | Codigo | I           | Q           |
# |--------|-------------|-------------|
# | 0000    | 1  | 1 |
# | 0001    | 3  | 1 |
# | 0010    | 3 | 3 |
# | 0011    | 1 | 3 |
# | 0100    | -1 | 1 |
# | 0101    | -1 | 3 |
# | 0110    | -3  | 3 |
# | 0111    | -3  | 1 |
# | 1000    | -1  | -1 |
# | 1001    | -3  | -1 |
# | 1010    | -3 | -3 |
# | 1011    | -1 | -3 |
# | 1100    | 1 | -1 |
# | 1101    | 1 | -3 |
# | 1110    | 3  | -3 |
# | 1111    | 3  | -1 |
#
# c) $R = \frac{N}{ts} = \frac{4}{4μS} = 1Mbps $
#
# d) Ancho de banda minimimo: Bmin = D = $\frac{R}{l}$ = $\frac{1Mbps}{4 bits} = 250kHz $

# %% [markdown]
# # Ejercicio 5
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# a)  Podemos calcular la potencia de un cuadrante y multiplicarla por los demas:
#
# $$ P_{16QAM} = \frac{P_{1}+2*P_{2}+P_{3}}{4} = \frac{20Ac^2}{50*4} = 250μW → Ac = 0.05 V$$
#
#
# Hacemos uso de los valores calculados:
#
# $$ P_{1} = \frac{(3Ac)^2+(3Ac)^2}{2*50} = 9\frac{Ac^2}{50}$$
#
# $$ P_{2} = \frac{(3Ac)^2+(Ac)^2}{2*50} = 5\frac{Ac^2}{50}$$
#
# $$ P_{3} = \frac{(Ac)^2+(Ac)^2}{2*50} = \frac{Ac^2}{50}$$
#
# $$ P_{4} = \frac{(5Ac)^2+(Ac)^2}{2*50} = \frac{13Ac^2}{50}$$
#
# $$ P_{5} = \frac{(7Ac)^2+(Ac)^2}{2*50} = \frac{25Ac^2}{50}$$
#
# $$ P_{6} = \frac{(7Ac)^2+(3Ac)^2}{2*50} = \frac{29Ac^2}{50}$$
#
# $$ P_{7} = \frac{(7Ac)^2+(5Ac)^2}{2*50} = \frac{37Ac^2}{50}$$
#
# $$ P_{8} = \frac{(7Ac)^2+(7Ac)^2}{2*50} = \frac{49Ac^2}{50}$$
#
# $$ P_{9} = \frac{(5Ac)^2+(5Ac)^2}{2*50} = \frac{25Ac^2}{50}$$
#
# $$ P_{10} = \frac{(5Ac)^2+(3Ac)^2}{2*50} = \frac{17Ac^2}{50}$$
#
#
# Hay que tener en cuenta que aquellas que no esten en la diagonal, se repetiran para el calculo de potencia:
#
# $$ P_{16QAM} = \frac{P_{1}+2*P_{2}+P_{3}+P_{9}+P_{8}+2*P_{4}+2*P_{5}+2*P_{6}+2*P_{7}+2*P_{10}}{4} = \frac{336Ac^2}{50*4} = 4.2mW = 12.465 dBm$$
#
#
# b)  Factor de cresta 16QAM:
#
# $$ \sqrt{\frac{P_{max}}{P_{med}}} = \sqrt{\frac{9\frac{Ac^2}{50}}{5\frac{Ac^2}{50}}} = 1.34 $$
#
# Factor de cresta 64QAM:
#
# $$ \sqrt{\frac{P_{max}}{P_{med}}} = \sqrt{\frac{\frac{49Ac^2}{50}}{\frac{21Ac^2}{50}}} = 2.3333 = \frac{7}{3} $$

# %% [markdown]
# ### Entrega 2
#
# a)
# Hay que tener en cuenta que aquellas que no esten en la diagonal, se repetiran para el calculo de potencia:
#
# $$ P_{64QAM} = \frac{P_{1}+2*P_{2}+P_{3}+P_{9}+P_{8}+2*P_{4}+2*P_{5}+2*P_{6}+2*P_{7}+2*P_{10}}{16} = \frac{336Ac^2}{50*16} = 1.05mW = 0.212 dBm$$
#
# b)
#
# $$ \sqrt{\frac{P_{max}}{P_{med}}} = \sqrt{\frac{18\frac{Ac^2}{50}}{5\frac{Ac^2}{50}}} = 1.897 $$
#
# Factor de cresta 64QAM:
#
# $$ \sqrt{\frac{P_{max}}{P_{med}}} = \sqrt{\frac{\frac{98Ac^2}{50}}{\frac{21Ac^2}{50}}} = 2.16 $$

# %% [markdown]
# # Ejercicio 6
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# a) $ F_{c} = \frac{ f_{0} - f_{1} }{2} = 1900 Hz $
#
# $ ΔF = 300 Hz $
#
# b) El ancho de banda estara dado por la suma de la separacion de 600Hz mas la mitad de cada uno de los anchos de banda minimo en f1 y f2, osea, 300Hz/2.
#
# Por lo tanto:
#
# $$ B_{min} = 900 Hz $$
#
# c) Condicion de ortogonalidad:
#
# $$ 2ΔF = f1 - f2 = \frac{nR}{2} $$
#
# $$ 600 Hz = \frac{nR}{2} → n = 4 $$
#
# Como es un numero entero, podemos decir que cumple con la condicion de ortogonalidad.
#
# d) $$ \frac{S}{N} = 7.093dB = 5.12 $$

# %%
SNR = 5.12

eta = 10**(-17)

total_bw = 600

print("Potencia de señal de entrada: ", SNR * eta * total_bw, "watts")
# Out:
# Potencia de señal de entrada:  3.072e-14 watts

# %% [markdown]
# e) ![image.png](data:image/png;base64,...)

# %% [markdown]
# f) Utilizando el mismo ancho de banda (900Hz), calculamos la tasa de informacion con 16QAM:
#
# $R = 900Hz\cdot l = 900Hz\cdot4 = 3.6 kbps $

# %% [markdown]
# ### Entrega 2

# %%
SNR = 5.12

eta = 10**(-17)

total_bw = 600*1.5

print("Potencia de señal de entrada: ", SNR * eta * total_bw, "watts")
# Out:
# Potencia de señal de entrada:  4.6080000000000004e-14 watts

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La frecuencia Fc corresponde con la de portadora que se detallo anteriormente. Las demas son las de enunciado.

# %% [markdown]
# # Ejercicio 7
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# N = 64
# D1P = 2kHz
#
# a) $R_{OFDM} = 256kbps$
#
# $R_{1P} = \frac{256kbps}{64} = 24kpbs $
#
# $ D_{1P} = 2kHz $
#
# $ l = \frac{R}{D} = 2 $
#
# Por lo tanto es QAM o QBPSK.
#
# b) $Ts_{OFDM} = \frac{64*2}{256kbps} = 0.5mS $
#
# c) $ BT_{min} = 128kHz $
#
# d) $ Ts = \frac{2}{256kHz} = 7.8125μS $
#
# e) $ BT_{min} = 128kHz $
#
# f) La eficiencia es la misma, la ventaja de OFDM es que aumenta los tiempos de simbolos que resulta una ventaja a la hora de enfrentarse a los caminos multiples de la señal.

# %% [markdown]
# # Ejercicio 8
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# a) Tiempo de simbolo:
#
# $$ Ts_{OFDM} = \frac{2048*4}{8Mbps} = 1.024mS $$
#
# b)
# $$ BT_{min} = 2MHz $$
#
# c) $$ F_{centrales} = F_{c} \pm \frac{D_{1P}}{2} $$
#
# $$ F_{sup} = F_{c} + \frac{D_{1P}}{2} + 1023 D_{1P}  $$
#
# $$ F_{sup} = F_{c} + \frac{D_{1P}}{2} + 1022 D_{1P}  $$
#
# $$ F_{sup} = F_{c} - \frac{D_{1P}}{2} - 1023 D_{1P}  $$
#
# $$ F_{sup} = F_{c} - \frac{D_{1P}}{2} - 1022 D_{1P}  $$
#
# d) Se visualizaran 2048 palitos separadas D1P
#
# e) $ F_{osc} = F_{c} + \frac{D1P}{2} = 3.9GHZ + \frac{976,5625}{2} $
#
# f) Tiempo de simbolos = $\frac{1}{D} = 1.25μS$
#
# Siendo D = $ \frac{8Mbps}{10bits} = 800kHz $

# %% [markdown]
# # Ejercicio 9
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Entrega 1

# %% [markdown]
# a) $ Rc = \frac{2^r - 1}{532,81.10^{-6} s} = 1.92000901 Mcps$
#
# b) BT = 2RC = 3.84MHz
#
# c) GP = $\frac{Rc}{Rb} = 100 = 20dB$
#
# d) Se podria modificar el clock del reloj o aumentar la cantidad de registros.
#
# Nuevo clock: $53.281.10^{-6} s$
#
# e) BT = 38.4001802 MHz
